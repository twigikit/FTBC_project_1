# %%
import requests
import json

# %%
url = "https://api.data.abs.gov.au/data/jv/all?startPeriod=2020&format=jsondata"
requests.get(url)
response_data = requests.get(url)
response_content = response_data.content
data = response_data.json()
data
# Out:
# {'meta': {'schema': 'https://raw.githubusercontent.com/sdmx-twg/sdmx-json/master/data-message/tools/schemas/1.0/sdmx-json-data-schema.json',
#   'id': 'IREF005409',
#   'prepared': '2022-10-25T21:31:50Z',
#   'test': False,
#   'contentLanguages': ['en'],
#   'sender': {'id': '_Stat_V8', 'name': 'unknown', 'names': {'en': 'unknown'}}},
#  'data': {'dataSets': [{'action': 'Information',
#     'links': [{'urn': 'urn:sdmx:org.sdmx.infomodel.datastructure.DataStructure=ABS:JV(1.0.0)',
#       'rel': 'DataStructure'}],
#     'annotations': [0, 1, 2, 3, 4, 5],
#     'series': {'0:0:0:0:0:0': {'attributes': [0, 0],
#       'annotations': [],
#       'observations': {'0': [29.8],
#        '1': [19.7],
#        '2': [28.4],
#        '3': [37.7],
#        '4': [39.1],
#        '5': [47.7],
#        '6': [51.2],
#        '7': [60.2],
#        '8': [60.2],
#        '9': [68.9],
#        '10': [74.3]}},
#      '1:0:1:0:0:0': {'attributes': [0, 0],
#       'annotations': [],
#       'observations': {'0': [0.7],
#        '1': [0.7],
#        '2': [0.8],
#        '3': [1.1],
#        '4': [0.9],
#        '5': [0.9],
#        '6': [1],
#        '7': [1],
#        '8': [1],
#        '9': [1],
#        '10': [1.1]}},
#      '0:0:2:0:1:0': {'attributes': [0, 0],
#       'annotations': [],
#       'observations': {'0': [59.7],
#        '1': [28.7],
#        '2': [45.8],
#        '3': [58.4],
#        '4': [65.6],
#        '5': [87.6],
#        '6': [81.3],
#        '7': [106],
#        '8': [101.8],
#        '9': [120.1],
#        '10': [126.6]}},
#      '0:1:2:1:0:0': {'attributes': [0, 0],
#       'annotations': [],
#       'observations': {'0': [None],
#        '1': [None],
#        '2': [None],
#        '3': [None],
#        '4': [None]}},
#      '1:2:2:0:2:0': {'attributes': [0, 0],
#       'annotations': [],
#       'observations': {'0': [3.2],
#        '1': [3.2],
#        '2': [3.7],
#        '3': [3.5],
#        '4': [4.1],
#        '5': [4.7],
#        '6': [6.1],
#        '7': [5.1],
#        '8': [5],
#        '9': [5.3],
#        '10': [5.8]}},
#      '1:2:2:0:3:0': {'attributes': [0, 0],
#       'annotations': [],
#       'observations': {'0': [0.2],
#        '1': [0.2],
#        '2': [0.7],
#        '3': [0.5],
#        '4': [0.6],
#        '5': [0.5],
#        '6': [0.8],
#        '7': [0.9],
#        '8': [1.6],
#        '9': [0.9],
#        '10': [0.9]}},
#      '1:1:2:0:3:0': {'attributes': [0, 0],
#       'annotations': [],
#       'observations': {'0': [0.2],
#        '1': [0.1],
#        '2': [0.2],
#        '3': [0.3],
#        '4': [0.3],
#        '5': [0.2],
#        '6': [0.4],
#        '7': [0.1],
#        '8': [0.2],
#        '9': [0.3],
#        '10': [0.3]}},
#      '0:0:3:0:0:0': {'attributes': [0, 0],
#       'annotations': [],
#       'observations': {'0': [12.2],
#        '1': [7],
#        '2': [13.5],
#        '3': [15.3],
#        '4': [16.6],
#        '5': [20.7],
#        '6': [23.2],
#        '7': [29.5],
#        '8': [30.6],
#        '9': [28.9],
#        '10': [28.3]}},
#      '0:0:4:0:0:0': {'attributes': [0, 0],
#       'annotations': [],
#       'observations': {'0': [2.1],
#        '1': [1.6],
#        '2': [1.9],
#        '3': [2.2],
#        '4': [2.7],
#        '5': [3],
#        '6': [3],
#        '7': [3.5],
#        '8': [4],
#        '9': [4.2],
#        '10': [4.4]}},
#      '1:0:5:0:0:0': {'attributes': [0, 0],
#       'annotations': [],
#       'observations': {'0': [0.3],
#        '1': [0.2],
#        '2': [0.3],
#        '3': [0.4],
#        '4': [0.4],
#        '5': [0.4],
#        '6': [0.3],
#        '7': [0.3],
#        '8': [0.5],
#        '9': [0.4],
#        '10': [0.3]}},
#      '0:0:2:0:4:0': {'attributes': [0, 0],
#       'annotations': [],
#       'observations': {'0': [3.4],
#        '1': [1.9],
#        '2': [3.4],
#        '3': [5.1],
#        '4': [5.7],
#        '5': [6.5],
#        '6': [5.8],
#        '7': [6.8],
#        '8': [7.3],
#        '9': [7.5],
#        '10': [6.3]}},
#      '0:0:2:1:0:0': {'attributes': [0, 0],
#       'annotations': [],
#       'observations': {'0': [None],
#        '1': [None],
#        '2': [None],
#        '3': [None],
#        '4': [None]}},
#      '0:2:2:0:1:0': {'attributes': [0, 0],
#       'annotations': [],
#       'observations': {'0': [53.7],
#        '1': [24.3],
#        '2': [40.6],
#        '3': [52.8],
#        '4': [59.5],
#        '5': [80.9],
#        '6': [74],
#        '7': [97.5],
#        '8': [93.7],
#        '9': [110.8],
#        '10': [116.3]}},
#      '0:2:2:0:4:0': {'attributes': [0, 0],
#       'annotations': [],
#       'observations': {'0': [2.9],
#        '1': [1.6, 0, None],
#        '2': [2.8],
#        '3': [4.4],
#        '4': [5.1],
#        '5': [5.9],
#        '6': [4.9],
#        '7': [5.7],
#        '8': [6.6],
#        '9': [6.7],
#        '10': [5.5]}},
#      '0:2:2:1:0:0': {'attributes': [0, 0],
#       'annotations': [],
#       'observations': {'0': [None],
#        '1': [None],
#        '2': [None],
#        '3': [None],
#        '4': [None]}},
#      '1:0:2:0:2:0': {'attributes': [0, 0],
#       'annotations': [],
#       'observations': {'0': [3.2],
#        '1': [3.2],
#        '2': [3.8],
#        '3': [3.6],
#        '4': [4.2],
#        '5': [4.7],
#        '6': [6.1],
#        '7': [5.2],
#        '8': [5.1],
#        '9': [5.5],
#        '10': [5.9]}},
#      '0:1:2:0:5:0': {'attributes': [0, 0],
#       'annotations': [],
#       'observations': {'0': [7.9],
#        '1': [6.3],
#        '2': [7.2],
#        '3': [8.2],
#        '4': [8.1],
#        '5': [10.1],
#        '6': [9.9],
#        '7': [9.8],
#        '8': [11.3],
#        '9': [12.9],
#        '10': [14.6]}},
#      '0:1:2:0:4:0': {'attributes': [0, 0],
#       'annotations': [],
#       'observations': {'0': [0.5],
#        '1': [0.3],
#        '2': [0.6],
#        '3': [0.8],
#        '4': [0.5],
#        '5': [0.6],
#        '6': [0.9],
#        '7': [1.1],
#        '8': [0.8],
#        '9': [0.8],
#        '10': [0.8]}},
#      '1:0:2:0:3:0': {'attributes': [0, 0],
#       'annotations': [],
#       'observations': {'0': [0.3],
#        '1': [0.2],
#        '2': [0.7],
#        '3': [0.6],
#        '4': [0.7],
#        '5': [0.5],
#        '6': [0.9],
#        '7': [0.9],
#        '8': [1.6],
#        '9': [0.9],
#        '10': [0.9]}},
#      '1:0:2:0:6:0': {'attributes': [0, 0],
#       'annotations': [],
#       'observations': {'0': [0.9],
#        '1': [0.4],
#        '2': [0.5],
#        '3': [1],
#        '4': [0.8],
#        '5': [0.9],
#        '6': [0.8],
#        '7': [1],
#        '8': [1],
#        '9': [1.3],
#        '10': [0.9]}},
#      '0:0:2:0:5:0': {'attributes': [0, 0],
#       'annotations': [],
#       'observations': {'0': [79.3],
#        '1': [39.8],
#        '2': [62.2],
#        '3': [82.7],
#        '4': [94],
#        '5': [112.8],
#        '6': [95.2],
#        '7': [120.9],
#        '8': [130],
#        '9': [145.1],
#        '10': [150.8]}},
#      '0:0:5:0:0:0': {'attributes': [0, 0],
#       'annotations': [],
#       'observations': {'0': [6.5],
#        '1': [4.3],
#        '2': [5.6],
#        '3': [6.3],
#        '4': [7.5],
#        '5': [8.3],
#        '6': [8.4],
#        '7': [9.7],
#        '8': [10.6],
#        '9': [11.2],
#        '10': [10.6]}},
#      '0:2:2:0:7:0': {'attributes': [0, 0],
#       'annotations': [],
#       'observations': {'0': [25.4],
#        '1': [15.4],
#        '2': [30.2],
#        '3': [35],
#        '4': [36.8],
#        '5': [43.3],
#        '6': [48.5],
#        '7': [57],
#        '8': [62.6],
#        '9': [60.9],
#        '10': [56.6]}},
#      '0:2:2:0:3:0': {'attributes': [0, 0],
#       'annotations': [],
#       'observations': {'0': [2.1],
#        '1': [1.3],
#        '2': [3.6],
#        '3': [3.5],
#        '4': [3.8],
#        '5': [4.1],
#        '6': [5],
#        '7': [5.2],
#        '8': [7.1],
#        '9': [6.3],
#        '10': [6.4]}},
#      '1:0:2:0:0:0': {'attributes': [0, 0],
#       'annotations': [],
#       'observations': {'0': [7.6],
#        '1': [5.6],
#        '2': [8.1],
#        '3': [7.8],
#        '4': [8.9],
#        '5': [11.1],
#        '6': [10.2],
#        '7': [10.7],
#        '8': [11.2],
#        '9': [11.3],
#        '10': [12.7]}},
#      '0:1:2:0:1:0': {'attributes': [0, 0],
#       'annotations': [],
#       'observations': {'0': [6],
#        '1': [4.4],
#        '2': [5.1],
#        '3': [5.6],
#        '4': [6.2],
#        '5': [6.7],
#        '6': [7.3],
#        '7': [8.5],
#        '8': [8.1],
#        '9': [9.3],
#        '10': [10.3]}},
#      '1:2:2:0:4:0': {'attributes': [0, 0],
#       'annotations': [],
#       'observations': {'0': [0.4],
#        '1': [0.4],
#        '2': [0.4],
#        '3': [0.9],
#        '4': [0.8],
#        '5': [0.9],
#        '6': [0.8],
#        '7': [1.1],
#        '8': [1.1],
#        '9': [0.8],
#        '10': [0.8]}},
#      '1:1:2:0:1:0': {'attributes': [0, 0],
#       'annotations': [],
#       'observations': {'0': [0.3],
#        '1': [0.2],
#        '2': [0.2],
#        '3': [0.3],
#        '4': [0.3],
#        '5': [0.4],
#        '6': [0.4],
#        '7': [0.7],
#        '8': [0.3],
#        '9': [0.7],
#        '10': [0.6]}},
#      '1:1:2:0:4:0': {'attributes': [0, 0],
#       'annotations': [],
#       'observations': {'0': [0],
#        '1': [0],
#        '2': [0],
#        '3': [0.2],
#        '4': [0.1],
#        '5': [0.1],
#        '6': [0.1],
#        '7': [0.1],
#        '8': [0.1],
#        '9': [0.1],
#        '10': [0.1]}},
#      '0:0:6:0:0:0': {'attributes': [0, 0],
#       'annotations': [],
#       'observations': {'0': [12.6],
#        '1': [6.5],
#        '2': [9.9],
#        '3': [13.4],
#        '4': [14],
#        '5': [17.8],
#        '6': [14.4],
#        '7': [16.7],
#        '8': [21.7],
#        '9': [19.2],
#        '10': [20.5]}},
#      '0:0:7:0:0:0': {'attributes': [0, 0],
#       'annotations': [],
#       'observations': {'0': [14.7],
#        '1': [5, 0, None],
#        '2': [13.5],
#        '3': [22.4],
#        '4': [27.6],
#        '5': [38.2],
#        '6': [27.6],
#        '7': [45.8],
#        '8': [46.1],
#        '9': [51.9],
#        '10': [59.1]}},
#      '0:0:8:0:0:0': {'attributes': [0, 0],
#       'annotations': [],
#       'observations': {'0': [7.7],
#        '1': [3.6],
#        '2': [6.4],
#        '3': [6.7],
#        '4': [8.5],
#        '5': [10.5],
#        '6': [9.8],
#        '7': [10.2],
#        '8': [11.6],
#        '9': [12.7],
#        '10': [11.2]}},
#      '0:0:9:0:0:0': {'attributes': [0, 0],
#       'annotations': [],
#       'observations': {'0': [2],
#        '1': [0.1, 1, None],
#        '2': [1.2],
#        '3': [4],
#        '4': [2.6],
#        '5': [5.4],
#        '6': [3.9],
#        '7': [7.4],
#        '8': [6.2],
#        '9': [7.2],
#        '10': [6.6]}},
#      '1:0:4:0:0:0': {'attributes': [0, 0],
#       'annotations': [],
#       'observations': {'0': [0.2],
#        '1': [0.2],
#        '2': [0.2],
#        '3': [0.2],
#        '4': [0.2],
#        '5': [0.4],
#        '6': [0.3],
#        '7': [0.4],
#        '8': [0.3],
#        '9': [0.3],
#        '10': [0.3]}},
#      '1:0:6:0:0:0': {'attributes': [0, 0],
#       'annotations': [],
#       'observations': {'0': [1.8],
#        '1': [1.6],
#        '2': [1.9],
#        '3': [2.1],
#        '4': [2.2],
#        '5': [2.2],
#        '6': [2.2],
#        '7': [2.1],
#        '8': [2.5],
#        '9': [2.4],
#        '10': [2.4]}},
#      '1:0:10:0:0:0': {'attributes': [0, 0],
#       'annotations': [],
#       'observations': {'0': [2.5],
#        '1': [1.5],
#        '2': [2.1],
#        '3': [2.5],
#        '4': [2.8],
#        '5': [3],
#        '6': [3.3],
#        '7': [3.6],
#        '8': [3.4],
#        '9': [3.2],
#        '10': [3.1]}},
#      '1:0:8:0:0:0': {'attributes': [0, 0],
#       'annotations': [],
#       'observations': {'0': [0.9],
#        '1': [0.6],
#        '2': [1.2],
#        '3': [1],
#        '4': [1],
#        '5': [1.3],
#        '6': [1.3],
#        '7': [1.3],
#        '8': [1.2],
#        '9': [1.3],
#        '10': [1.2]}},
#      '0:1:2:0:2:0': {'attributes': [0, 0],
#       'annotations': [],
#       'observations': {'0': [3.5],
#        '1': [2.3],
#        '2': [2.9],
#        '3': [3.9],
#        '4': [4.4],
#        '5': [4.4],
#        '6': [4.4],
#        '7': [5.4],
#        '8': [6.1],
#        '9': [6.4],
#        '10': [7.1]}},
#      '0:1:2:0:8:0': {'attributes': [0, 0],
#       'annotations': [],
#       'observations': {'0': [1.7],
#        '1': [1.6],
#        '2': [1.8],
#        '3': [2.2],
#        '4': [2],
#        '5': [2.6],
#        '6': [2.4],
#        '7': [2.9],
#        '8': [2.6],
#        '9': [2.5],
#        '10': [2.8]}},
#      '0:1:2:0:7:0': {'attributes': [0, 0],
#       'annotations': [],
#       'observations': {'0': [2.2],
#        '1': [1.4, 0, None],
#        '2': [2],
#        '3': [2.4],
#        '4': [3.2],
#        '5': [2.9],
#        '6': [3.5],
#        '7': [3.9],
#        '8': [3.9],
#        '9': [4.3],
#        '10': [4.1]}},
#      '0:1:2:2:0:0': {'attributes': [0, 0],
#       'annotations': [],
#       'observations': {'0': [24.9],
#        '1': [17.8],
#        '2': [22.2],
#        '3': [25.7],
#        '4': [28],
#        '5': [30.1],
#        '6': [31.3],
#        '7': [34.7],
#        '8': [37.5],
#        '9': [41],
#        '10': [45.3]}},
#      '1:1:2:0:2:0': {'attributes': [0, 0],
#       'annotations': [],
#       'observations': {'0': [0.2],
#        '1': [0.1],
#        '2': [0.4],
#        '3': [0.5],
#        '4': [0.8],
#        '5': [0.6],
#        '6': [0.2],
#        '7': [1.1],
#        '8': [1.3],
#        '9': [1.2],
#        '10': [1.2]}},
#      '0:0:11:0:0:0': {'attributes': [0, 0],
#       'annotations': [],
#       'observations': {'0': [3.4],
#        '1': [2],
#        '2': [2.4],
#        '3': [2.7],
#        '4': [3.8],
#        '5': [3.7],
#        '6': [3.5],
#        '7': [4.7],
#        '8': [4.5],
#        '9': [5.3],
#        '10': [5.4]}},
#      '0:0:12:0:0:0': {'attributes': [0, 0],
#       'annotations': [],
#       'observations': {'0': [3.2],
#        '1': [1, 0, None],
#        '2': [3.6, 0, None],
#        '3': [4.4],
#        '4': [4.6],
#        '5': [7.8],
#        '6': [5.8],
#        '7': [8.5],
#        '8': [9.3],
#        '9': [9.7],
#        '10': [10.1]}},
#      '0:0:10:0:0:0': {'attributes': [0, 0],
#       'annotations': [],
#       'observations': {'0': [31.2],
#        '1': [17.5],
#        '2': [24.2],
#        '3': [26.8],
#        '4': [28.6],
#        '5': [35.2],
#        '6': [36.8],
#        '7': [39.9],
#        '8': [40.6],
#        '9': [38.2],
#        '10': [38]}},
#      '1:0:7:0:0:0': {'attributes': [0, 0],
#       'annotations': [],
#       'observations': {'0': [2.4],
#        '1': [1.7],
#        '2': [2.9],
#        '3': [3.6],
#        '4': [3.7],
#        '5': [3.7],
#        '6': [4.2],
#        '7': [4.4],
#        '8': [4.8],
#        '9': [4.3],
#        '10': [6.2]}},
#      '1:0:11:0:0:0': {'attributes': [0, 0],
#       'annotations': [],
#       'observations': {'0': [0.4],
#        '1': [0.2],
#        '2': [0.3],
#        '3': [0.3],
#        '4': [0.4],
#        '5': [0.3],
#        '6': [0.4],
#        '7': [0.5],
#        '8': [0.4],
#        '9': [0.5],
#        '10': [0.4]}},
#      '1:0:12:0:0:0': {'attributes': [0, 0],
#       'annotations': [],
#       'observations': {'0': [0.7],
#        '1': [0.4],
#        '2': [0.9],
#        '3': [0.8],
#        '4': [0.8],
#        '5': [1.3],
#        '6': [1],
#        '7': [1.3],
#        '8': [1.4],
#        '9': [1.6],
#        '10': [1.6]}},
#      '1:2:2:0:6:0': {'attributes': [0, 0],
#       'annotations': [],
#       'observations': {'0': [0.9],
#        '1': [0.4],
#        '2': [0.5],
#        '3': [1],
#        '4': [0.8],
#        '5': [0.9],
#        '6': [0.8],
#        '7': [1],
#        '8': [1],
#        '9': [1.3],
#        '10': [0.9]}},
#      '1:1:2:0:8:0': {'attributes': [0, 0],
#       'annotations': [],
#       'observations': {'0': [0.1],
#        '1': [0.1],
#        '2': [0.1],
#        '3': [0.1],
#        '4': [0.1],
#        '5': [0.1],
#        '6': [0.2],
#        '7': [0.3],
#        '8': [0.1],
#        '9': [0.1],
#        '10': [0.1]}},
#      '0:0:13:0:0:0': {'attributes': [0, 0],
#       'annotations': [],
#       'observations': {'0': [18.9],
#        '1': [11.4],
#        '2': [18.5],
#        '3': [25.7],
#        '4': [24.9],
#        '5': [34.3],
#        '6': [33.6],
#        '7': [36],
#        '8': [29.1],
#        '9': [40.3],
#        '10': [46.1]}},
#      '1:0:14:0:0:0': {'attributes': [0, 0],
#       'annotations': [],
#       'observations': {'0': [2.8],
#        '1': [2.1],
#        '2': [2.8],
#        '3': [2.8],
#        '4': [3.9],
#        '5': [4.4],
#        '6': [3.5],
#        '7': [3.9],
#        '8': [3.5],
#        '9': [4.8],
#        '10': [4]}},
#      '0:0:2:0:8:0': {'attributes': [0, 0],
#       'annotations': [],
#       'observations': {'0': [11.7],
#        '1': [6.8],
#        '2': [12.5],
#        '3': [15.6],
#        '4': [19.3],
#        '5': [21.3],
#        '6': [18],
#        '7': [23.7],
#        '8': [24.5],
#        '9': [24.5],
#        '10': [25.2]}},
#      '0:2:2:0:6:0': {'attributes': [0, 0],
#       'annotations': [],
#       'observations': {'0': [4.9],
#        '1': [2.5],
#        '2': [3.7],
#        '3': [6],
#        '4': [6],
#        '5': [6.7],
#        '6': [6.1],
#        '7': [7.7],
#        '8': [8.5],
#        '9': [8.8],
#        '10': [7.5]}},
#      '1:0:2:0:5:0': {'attributes': [0, 0],
#       'annotations': [],
#       'observations': {'0': [4.6],
#        '1': [3.1],
#        '2': [4],
#        '3': [5.6],
#        '4': [5.9],
#        '5': [6.4],
#        '6': [4.9],
#        '7': [6.1],
#        '8': [5.7],
#        '9': [6.8],
#        '10': [7.6]}},
#      '1:2:2:0:7:0': {'attributes': [0, 0],
#       'annotations': [],
#       'observations': {'0': [2.7],
#        '1': [2],
#        '2': [3.3],
#        '3': [3.2],
#        '4': [3.3],
#        '5': [4.1],
#        '6': [4],
#        '7': [3.7],
#        '8': [4.1],
#        '9': [4.7],
#        '10': [3.8]}},
#      '0:0:2:0:0:0': {'attributes': [0, 0],
#       'annotations': [],
#       'observations': {'0': [229.5],
#        '1': [124.5],
#        '2': [208],
#        '3': [259.2],
#        '4': [291],
#        '5': [355.4],
#        '6': [337],
#        '7': [404.6],
#        '8': [426.8],
#        '9': [461],
#        '10': [475]}},
#      '1:0:9:0:0:0': {'attributes': [0, 0],
#       'annotations': [],
#       'observations': {'0': [0.2],
#        '1': [0.1],
#        '2': [0.1],
#        '3': [0.7],
#        '4': [0.3],
#        '5': [0.6],
#        '6': [0.7],
#        '7': [0.7],
#        '8': [0.6],
#        '9': [0.7],
#        '10': [0.5]}},
#      '1:0:15:0:0:0': {'attributes': [0, 0],
#       'annotations': [],
#       'observations': {'0': [1.6],
#        '1': [1],
#        '2': [1.7],
#        '3': [1.7],
#        '4': [2.2],
#        '5': [2.1],
#        '6': [2.3],
#        '7': [2.4],
#        '8': [2.3],
#        '9': [2.3],
#        '10': [2.5]}},
#      '0:1:2:0:6:0': {'attributes': [0, 0],
#       'annotations': [],
#       'observations': {'0': [1.7],
#        '1': [1],
#        '2': [1.9],
#        '3': [1.9],
#        '4': [2.1],
#        '5': [2.1],
#        '6': [1.9],
#        '7': [2.2],
#        '8': [3],
#        '9': [3.5],
#        '10': [4.5]}},
#      '1:1:2:0:7:0': {'attributes': [0, 0],
#       'annotations': [],
#       'observations': {'0': [0.3],
#        '1': [0.4],
#        '2': [0.3],
#        '3': [0.3],
#        '4': [0.6],
#        '5': [0.4],
#        '6': [0.4],
#        '7': [0.5],
#        '8': [0.6],
#        '9': [0.5],
#        '10': [0.5]}},
#      '1:1:2:0:0:0': {'attributes': [0, 0],
#       'annotations': [],
#       'observations': {'0': [1.4],
#        '1': [1.2],
#        '2': [1.3],
#        '3': [1.1],
#        '4': [1.6],
#        '5': [1.8],
#        '6': [1.2],
#        '7': [1.6],
#        '8': [1.9],
#        '9': [2.1],
#        '10': [2]}},
#      '1:1:2:0:5:0': {'attributes': [0, 0],
#       'annotations': [],
#       'observations': {'0': [1.4],
#        '1': [1.1],
#        '2': [1.2],
#        '3': [0.8],
#        '4': [1],
#        '5': [1.4],
#        '6': [0.8],
#        '7': [0.4],
#        '8': [1.1],
#        '9': [1.2],
#        '10': [1]}},
#      '0:0:2:0:6:0': {'attributes': [0, 0],
#       'annotations': [],
#       'observations': {'0': [6.6],
#        '1': [3.6],
#        '2': [5.6],
#        '3': [7.9],
#        '4': [8.2],
#        '5': [8.8],
#        '6': [8],
#        '7': [9.9],
#        '8': [11.5],
#        '9': [12.3],
#        '10': [12]}},
#      '0:2:2:0:8:0': {'attributes': [0, 0],
#       'annotations': [],
#       'observations': {'0': [10],
#        '1': [5.2],
#        '2': [10.6],
#        '3': [13.3],
#        '4': [17.3],
#        '5': [18.7],
#        '6': [15.5],
#        '7': [20.9],
#        '8': [21.9],
#        '9': [21.9],
#        '10': [22.4]}},
#      '0:1:2:0:0:0': {'attributes': [0, 0],
#       'annotations': [],
#       'observations': {'0': [24.4],
#        '1': [17.9],
#        '2': [22.3],
#        '3': [25.8],
#        '4': [27.5],
#        '5': [30.4],
#        '6': [31.5],
#        '7': [34.7],
#        '8': [37],
#        '9': [41.3],
#        '10': [45.5]}},
#      '0:1:2:0:3:0': {'attributes': [0, 0],
#       'annotations': [],
#       'observations': {'0': [0.8],
#        '1': [0.5],
#        '2': [0.6, 0, None],
#        '3': [0.8, 0, None],
#        '4': [1, 0, None],
#        '5': [0.9],
#        '6': [1.1, 0, None],
#        '7': [1],
#        '8': [1.3],
#        '9': [1.5],
#        '10': [1.3]}},
#      '1:0:2:0:1:0': {'attributes': [0, 0],
#       'annotations': [],
#       'observations': {'0': [3.6],
#        '1': [2.9],
#        '2': [3.7],
#        '3': [4.2],
#        '4': [4.5],
#        '5': [4.9],
#        '6': [5.5],
#        '7': [6],
#        '8': [5.1],
#        '9': [5.7],
#        '10': [6]}},
#      '0:0:16:0:0:0': {'attributes': [0, 0],
#       'annotations': [],
#       'observations': {'0': [7.5],
#        '1': [3.3],
#        '2': [5.5],
#        '3': [6.6],
#        '4': [9.3],
#        '5': [10.6],
#        '6': [11.5],
#        '7': [13.3],
#        '8': [14.7],
#        '9': [15.2],
#        '10': [17.7]}},
#      '0:0:15:0:0:0': {'attributes': [0, 0],
#       'annotations': [],
#       'observations': {'0': [9.4],
#        '1': [3.6, 0, None],
#        '2': [8.3],
#        '3': [10.6],
#        '4': [13.6],
#        '5': [15.4],
#        '6': [16],
#        '7': [16.1],
#        '8': [20.7],
#        '9': [21.1],
#        '10': [18.8]}},
#      '1:0:0:0:0:0': {'attributes': [0, 0],
#       'annotations': [],
#       'observations': {'0': [2.6],
#        '1': [2.3],
#        '2': [2.1],
#        '3': [2.6],
#        '4': [2.8],
#        '5': [3.6],
#        '6': [4.1],
#        '7': [3.9],
#        '8': [4.2],
#        '9': [4.1],
#        '10': [5]}},
#      '0:0:2:0:2:0': {'attributes': [0, 0],
#       'annotations': [],
#       'observations': {'0': [38.4],
#        '1': [25.2],
#        '2': [42.1],
#        '3': [47.9],
#        '4': [53.5],
#        '5': [67.2],
#        '6': [70.6],
#        '7': [70.3],
#        '8': [76.9],
#        '9': [78.6],
#        '10': [85.8]}},
#      '0:2:2:2:0:0': {'attributes': [0, 0],
#       'annotations': [],
#       'observations': {'0': [202.2],
#        '1': [111.4],
#        '2': [184.4],
#        '3': [228.5],
#        '4': [259.3],
#        '5': [340.3],
#        '6': [303],
#        '7': [362.8],
#        '8': [383],
#        '9': [439.9],
#        '10': [425.5]}},
#      '1:2:2:0:1:0': {'attributes': [0, 0],
#       'annotations': [],
#       'observations': {'0': [3.7],
#        '1': [2.9],
#        '2': [3.7],
#        '3': [4.1],
#        '4': [4.6],
#        '5': [4.9],
#        '6': [5.5],
#        '7': [6],
#        '8': [5.1],
#        '9': [5.5],
#        '10': [6.1]}},
#      '1:2:2:0:8:0': {'attributes': [0, 0],
#       'annotations': [],
#       'observations': {'0': [1.4],
#        '1': [0.8],
#        '2': [1.3],
#        '3': [1.5],
#        '4': [1.9],
#        '5': [2.1],
#        '6': [2.1],
#        '7': [2.5],
#        '8': [2.6],
#        '9': [2.4],
#        '10': [1.9]}},
#      '1:1:2:0:6:0': {'attributes': [0, 0],
#       'annotations': [],
#       'observations': {'0': [0.1],
#        '1': [0.1],
#        '2': [0.1],
#        '3': [0.2],
#        '4': [0.2],
#        '5': [0.1],
#        '6': [0.1],
#        '7': [0.3],
#        '8': [0.5],
#        '9': [0.3],
#        '10': [0.2]}},
#      '0:0:14:0:0:0': {'attributes': [0, 0],
#       'annotations': [],
#       'observations': {'0': [16.6],
#        '1': [8.3],
#        '2': [15.9],
#        '3': [17.9],
#        '4': [26.7],
#        '5': [29.9],
#        '6': [23.2],
#        '7': [30],
#        '8': [35.2],
#        '9': [39.9],
#        '10': [33.5]}},
#      '1:0:3:0:0:0': {'attributes': [0, 0],
#       'annotations': [],
#       'observations': {'0': [1.5],
#        '1': [1.4],
#        '2': [2.3],
#        '3': [2.1],
#        '4': [2.5],
#        '5': [2.3],
#        '6': [2.4],
#        '7': [3.2],
#        '8': [3.2],
#        '9': [2.7],
#        '10': [3.1]}},
#      '0:0:2:0:3:0': {'attributes': [0, 0],
#       'annotations': [],
#       'observations': {'0': [2.9],
#        '1': [1.7],
#        '2': [4.2],
#        '3': [4.2],
#        '4': [4.8],
#        '5': [5],
#        '6': [6.1],
#        '7': [6.2],
#        '8': [8.5],
#        '9': [7.7],
#        '10': [7.6]}},
#      '0:0:2:2:0:0': {'attributes': [0, 0],
#       'annotations': [],
#       'observations': {'0': [227.1],
#        '1': [129.2],
#        '2': [206.5],
#        '3': [254.3],
#        '4': [287.3],
#        '5': [370.5],
#        '6': [334.3],
#        '7': [397.5],
#        '8': [420.4],
#        '9': [480.9],
#        '10': [470.9]}},
#      '0:2:2:0:2:0': {'attributes': [0, 0],
#       'annotations': [],
#       'observations': {'0': [34.9],
#        '1': [22.9],
#        '2': [39.2],
#        '3': [44],
#        '4': [49.1],
#        '5': [62.8],
#        '6': [66.2],
#        '7': [64.9],
#        '8': [70.8],
#        '9': [72.2],
#        '10': [78.7]}},
#      '1:0:2:0:8:0': {'attributes': [0, 0],
#       'annotations': [],
#       'observations': {'0': [1.4],
#        '1': [0.8],
#        '2': [1.3],
#        '3': [1.5],
#        '4': [1.9],
#        '5': [2.1],
#        '6': [2.1],
#        '7': [2.4],
#        '8': [2.6],
#        '9': [2.4],
#        '10': [1.9]}},
#      '1:2:2:0:0:0': {'attributes': [0, 0],
#       'annotations': [],
#       'observations': {'0': [7.7],
#        '1': [5.6],
#        '2': [8],
#        '3': [8],
#        '4': [8.8],
#        '5': [10.9],
#        '6': [10.1],
#        '7': [10.6],
#        '8': [11.1],
#        '9': [11.3],
#        '10': [12.5]}},
#      '0:0:17:0:0:0': {'attributes': [0, 0],
#       'annotations': [],
#       'observations': {'0': [26.3],
#        '1': [13.1],
#        '2': [23.5],
#        '3': [27],
#        '4': [31.2],
#        '5': [31.9],
#        '6': [31.7],
#        '7': [37.1],
#        '8': [42.1],
#        '9': [42.9],
#        '10': [44.1]}},
#      '0:2:2:0:0:0': {'attributes': [0, 0],
#       'annotations': [],
#       'observations': {'0': [205.1],
#        '1': [106.5],
#        '2': [185.7],
#        '3': [233.3],
#        '4': [263.5],
#        '5': [325],
#        '6': [305.5],
#        '7': [369.9],
#        '8': [389.9],
#        '9': [419.7],
#        '10': [429.5]}},
#      '1:0:2:0:4:0': {'attributes': [0, 0],
#       'annotations': [],
#       'observations': {'0': [0.4],
#        '1': [0.4],
#        '2': [0.4],
#        '3': [1],
#        '4': [0.8],
#        '5': [0.9],
#        '6': [0.8],
#        '7': [1.1],
#        '8': [1.1],
#        '9': [0.8],
#        '10': [0.8]}},
#      '0:0:18:0:0:0': {'attributes': [0, 0],
#       'annotations': [],
#       'observations': {'0': [11.9],
#        '1': [7.8],
#        '2': [12.3],
#        '3': [12.8],
#        '4': [14.7],
#        '5': [17.9],
#        '6': [15.8],
#        '7': [17],
#        '8': [18.1],
#        '9': [20.2],
#        '10': [18.6]}},
#      '0:0:1:0:0:0': {'attributes': [0, 0],
#       'annotations': [],
#       'observations': {'0': [13.3],
#        '1': [8.6],
#        '2': [13.4],
#        '3': [16.7],
#        '4': [15],
#        '5': [17.2],
#        '6': [17.5],
#        '7': [18.9],
#        '8': [21.5],
#        '9': [24.1],
#        '10': [27.5]}},
#      '1:0:13:0:0:0': {'attributes': [0, 0],
#       'annotations': [],
#       'observations': {'0': [2],
#        '1': [2.3],
#        '2': [2.3],
#        '3': [3],
#        '4': [2.7],
#        '5': [3.2],
#        '6': [3.1],
#        '7': [2.9],
#        '8': [3],
#        '9': [3.6],
#        '10': [3.7]}},
#      '1:0:16:0:0:0': {'attributes': [0, 0],
#       'annotations': [],
#       'observations': {'0': [0.8],
#        '1': [0.4],
#        '2': [0.6],
#        '3': [0.8],
#        '4': [1.1],
#        '5': [1.3],
#        '6': [1.2],
#        '7': [1.1],
#        '8': [1.1],
#        '9': [0.9],
#        '10': [1.3]}},
#      '1:0:18:0:0:0': {'attributes': [0, 0],
#       'annotations': [],
#       'observations': {'0': [0.7],
#        '1': [0.5],
#        '2': [1.1],
#        '3': [1.1],
#        '4': [1.1],
#        '5': [1.7],
#        '6': [1.3],
#        '7': [1.3],
#        '8': [1.5],
#        '9': [1.5],
#        '10': [1.2]}},
#      '1:0:17:0:0:0': {'attributes': [0, 0],
#       'annotations': [],
#       'observations': {'0': [3.3],
#        '1': [2.9],
#        '2': [4.3],
#        '3': [3.5],
#        '4': [4],
#        '5': [3.9],
#        '6': [4.2],
#        '7': [4.1],
#        '8': [4.6],
#        '9': [4.3],
#        '10': [4.7]}},
#      '0:0:2:0:7:0': {'attributes': [0, 0],
#       'annotations': [],
#       'observations': {'0': [27.6],
#        '1': [16.8],
#        '2': [32.2],
#        '3': [37.4],
#        '4': [40],
#        '5': [46.2],
#        '6': [52.1],
#        '7': [60.8],
#        '8': [66.5],
#        '9': [65.2],
#        '10': [60.7]}},
#      '0:2:2:0:5:0': {'attributes': [0, 0],
#       'annotations': [],
#       'observations': {'0': [71.4],
#        '1': [33.4],
#        '2': [55],
#        '3': [74.4],
#        '4': [85.9],
#        '5': [102.7],
#        '6': [85.2],
#        '7': [111.1],
#        '8': [118.7],
#        '9': [132.2],
#        '10': [136.1]}},
#      '1:0:2:0:7:0': {'attributes': [0, 0],
#       'annotations': [],
#       'observations': {'0': [2.7],
#        '1': [2],
#        '2': [3.4],
#        '3': [3.2],
#        '4': [3.3],
#        '5': [4.1],
#        '6': [3.9],
#        '7': [3.7],
#        '8': [4.1],
#        '9': [4.6],
#        '10': [3.8]}},
#      '1:2:2:0:5:0': {'attributes': [0, 0],
#       'annotations': [],
#       'observations': {'0': [4.8],
#        '1': [3],
#        '2': [3.8],
#        '3': [5.8],
#        '4': [5.9],
#        '5': [6.3],
#        '6': [4.8],
#        '7': [6.1],
#        '8': [5.7],
#        '9': [7],
#        '10': [7.6]}}}}],
#   'structure': {'name': 'Job Vacancies',
#    'names': {'en': 'Job Vacancies'},
#    'description': 'Estimates of job vacancies classified by industry, sector and state/territory. Job vacancies data relate to the number of vacancies which exist on the actual survey reference date only, and not for a monthly or quarterly period. Unit of measure: Vacancies/RSE. Geographic coverage: Australia/State. Catalogue number: 6354.0',
#    'descriptions': {'en': 'Estimates of job vacancies classified by industry, sector and state/territory. Job vacancies data relate to the number of vacancies which exist on the actual survey reference date only, and not for a monthly or quarterly period. Unit of measure: Vacancies/RSE. Geographic coverage: Australia/State. Catalogue number: 6354.0'},
#    'dimensions': {'dataset': [],
#     'series': [{'id': 'MEASURE',
#       'name': 'Measure',
#       'names': {'en': 'Measure'},
#       'keyPosition': 0,
#       'roles': ['MEASURE'],
#       'values': [{'id': 'M1',
#         'order': 0,
#         'name': 'Job Vacancies',
#         'names': {'en': 'Job Vacancies'},
#         'annotations': [6]},
#        {'id': 'M2',
#         'order': 1,
#         'name': 'Standard Error of Job Vacancies',
#         'names': {'en': 'Standard Error of Job Vacancies'},
#         'annotations': [7]}]},
#      {'id': 'SECTOR',
#       'name': 'Sector',
#       'names': {'en': 'Sector'},
#       'keyPosition': 1,
#       'roles': ['SECTOR'],
#       'values': [{'id': '7',
#         'order': 0,
#         'name': 'Private and Public',
#         'names': {'en': 'Private and Public'},
#         'annotations': [8]},
#        {'id': '2',
#         'order': 2,
#         'name': 'Public',
#         'names': {'en': 'Public'},
#         'parent': '7',
#         'annotations': [9]},
#        {'id': '1',
#         'order': 1,
#         'name': 'Private',
#         'names': {'en': 'Private'},
#         'parent': '7',
#         'annotations': [10]}]},
#      {'id': 'INDUSTRY',
#       'name': 'Industry',
#       'names': {'en': 'Industry'},
#       'keyPosition': 2,
#       'roles': ['INDUSTRY'],
#       'values': [{'id': 'Q',
#         'order': 17,
#         'name': 'Health Care and Social Assistance',
#         'names': {'en': 'Health Care and Social Assistance'},
#         'parent': 'TOT',
#         'annotations': [11]},
#        {'id': 'O',
#         'order': 15,
#         'name': 'Public Administration and Safety',
#         'names': {'en': 'Public Administration and Safety'},
#         'parent': 'TOT',
#         'annotations': [12]},
#        {'id': 'TOT',
#         'order': 0,
#         'name': 'All Industries',
#         'names': {'en': 'All Industries'},
#         'annotations': [10]},
#        {'id': 'C',
#         'order': 3,
#         'name': 'Manufacturing',
#         'names': {'en': 'Manufacturing'},
#         'parent': 'TOT',
#         'annotations': [13]},
#        {'id': 'D',
#         'order': 4,
#         'name': 'Electricity, Gas, Water and Waste Services',
#         'names': {'en': 'Electricity, Gas, Water and Waste Services'},
#         'parent': 'TOT',
#         'annotations': [14]},
#        {'id': 'B',
#         'order': 2,
#         'name': 'Mining',
#         'names': {'en': 'Mining'},
#         'parent': 'TOT',
#         'annotations': [15]},
#        {'id': 'F',
#         'order': 6,
#         'name': 'Wholesale Trade',
#         'names': {'en': 'Wholesale Trade'},
#         'parent': 'TOT',
#         'annotations': [16]},
#        {'id': 'H',
#         'order': 8,
#         'name': 'Accommodation and Food Services',
#         'names': {'en': 'Accommodation and Food Services'},
#         'parent': 'TOT',
#         'annotations': [17]},
#        {'id': 'P',
#         'order': 16,
#         'name': 'Education and Training',
#         'names': {'en': 'Education and Training'},
#         'parent': 'TOT',
#         'annotations': [18]},
#        {'id': 'R',
#         'order': 18,
#         'name': 'Arts and Recreation Services',
#         'names': {'en': 'Arts and Recreation Services'},
#         'parent': 'TOT',
#         'annotations': [19]},
#        {'id': 'N',
#         'order': 14,
#         'name': 'Administrative and Support Services',
#         'names': {'en': 'Administrative and Support Services'},
#         'parent': 'TOT',
#         'annotations': [20]},
#        {'id': 'J',
#         'order': 10,
#         'name': 'Information Media and Telecommunications',
#         'names': {'en': 'Information Media and Telecommunications'},
#         'parent': 'TOT',
#         'annotations': [21]},
#        {'id': 'L',
#         'order': 12,
#         'name': 'Rental, Hiring and Real Estate Services',
#         'names': {'en': 'Rental, Hiring and Real Estate Services'},
#         'parent': 'TOT',
#         'annotations': [22]},
#        {'id': 'G',
#         'order': 7,
#         'name': 'Retail Trade',
#         'names': {'en': 'Retail Trade'},
#         'parent': 'TOT',
#         'annotations': [23]},
#        {'id': 'E',
#         'order': 5,
#         'name': 'Construction',
#         'names': {'en': 'Construction'},
#         'parent': 'TOT',
#         'annotations': [24]},
#        {'id': 'S',
#         'order': 19,
#         'name': 'Other Services',
#         'names': {'en': 'Other Services'},
#         'parent': 'TOT',
#         'annotations': [25]},
#        {'id': 'I',
#         'order': 9,
#         'name': 'Transport, Postal and Warehousing',
#         'names': {'en': 'Transport, Postal and Warehousing'},
#         'parent': 'TOT',
#         'annotations': [26]},
#        {'id': 'M',
#         'order': 13,
#         'name': 'Professional, Scientific and Technical Services',
#         'names': {'en': 'Professional, Scientific and Technical Services'},
#         'parent': 'TOT',
#         'annotations': [27]},
#        {'id': 'K',
#         'order': 11,
#         'name': 'Financial and Insurance Services',
#         'names': {'en': 'Financial and Insurance Services'},
#         'parent': 'TOT',
#         'annotations': [28]}]},
#      {'id': 'TSEST',
#       'name': 'Adjustment Type',
#       'names': {'en': 'Adjustment Type'},
#       'keyPosition': 3,
#       'roles': ['TSEST'],
#       'values': [{'id': '10',
#         'order': 0,
#         'name': 'Original',
#         'names': {'en': 'Original'},
#         'annotations': [29, 30]},
#        {'id': '30',
#         'order': 2,
#         'name': 'Trend',
#         'names': {'en': 'Trend'},
#         'annotations': [31, 32]},
#        {'id': '20',
#         'order': 1,
#         'name': 'Seasonally Adjusted',
#         'names': {'en': 'Seasonally Adjusted'},
#         'annotations': [33, 34]}],
#       'annotations': [35]},
#      {'id': 'REGION',
#       'name': 'Region',
#       'names': {'en': 'Region'},
#       'keyPosition': 4,
#       'roles': ['REGION'],
#       'values': [{'id': 'AUS',
#         'order': 0,
#         'name': 'Australia',
#         'names': {'en': 'Australia'},
#         'annotations': [10]},
#        {'id': '2',
#         'order': 2,
#         'name': 'Victoria',
#         'names': {'en': 'Victoria'},
#         'parent': 'AUS',
#         'annotations': [36]},
#        {'id': '3',
#         'order': 3,
#         'name': 'Queensland',
#         'names': {'en': 'Queensland'},
#         'parent': 'AUS',
#         'annotations': [37]},
#        {'id': '7',
#         'order': 7,
#         'name': 'Northern Territory',
#         'names': {'en': 'Northern Territory'},
#         'parent': 'AUS',
#         'annotations': [38]},
#        {'id': '6',
#         'order': 6,
#         'name': 'Tasmania',
#         'names': {'en': 'Tasmania'},
#         'parent': 'AUS',
#         'annotations': [8]},
#        {'id': '1',
#         'order': 1,
#         'name': 'New South Wales',
#         'names': {'en': 'New South Wales'},
#         'parent': 'AUS',
#         'annotations': [9]},
#        {'id': '8',
#         'order': 8,
#         'name': 'Australian Capital Territory',
#         'names': {'en': 'Australian Capital Territory'},
#         'parent': 'AUS',
#         'annotations': [39]},
#        {'id': '5',
#         'order': 5,
#         'name': 'Western Australia',
#         'names': {'en': 'Western Australia'},
#         'parent': 'AUS',
#         'annotations': [40]},
#        {'id': '4',
#         'order': 4,
#         'name': 'South Australia',
#         'names': {'en': 'South Australia'},
#         'parent': 'AUS',
#         'annotations': [41]}]},
#      {'id': 'FREQ',
#       'name': 'Frequency',
#       'names': {'en': 'Frequency'},
#       'keyPosition': 5,
#       'roles': ['FREQ'],
#       'values': [{'id': 'Q',
#         'order': 8,
#         'name': 'Quarterly',
#         'names': {'en': 'Quarterly'}}]}],
#     'observation': [{'id': 'TIME_PERIOD',
#       'name': 'Time Period',
#       'names': {'en': 'Time Period'},
#       'keyPosition': 6,
#       'roles': ['TIME_PERIOD'],
#       'values': [{'start': '2020-01-01T00:00:00Z',
#         'end': '2020-03-31T00:00:00Z',
#         'id': '2020-Q1',
#         'name': '2020-Q1',
#         'names': {'en': '2020-Q1'}},
#        {'start': '2020-04-01T00:00:00Z',
#         'end': '2020-06-30T00:00:00Z',
#         'id': '2020-Q2',
#         'name': '2020-Q2',
#         'names': {'en': '2020-Q2'}},
#        {'start': '2020-07-01T00:00:00Z',
#         'end': '2020-09-30T00:00:00Z',
#         'id': '2020-Q3',
#         'name': '2020-Q3',
#         'names': {'en': '2020-Q3'}},
#        {'start': '2020-10-01T00:00:00Z',
#         'end': '2020-12-31T00:00:00Z',
#         'id': '2020-Q4',
#         'name': '2020-Q4',
#         'names': {'en': '2020-Q4'}},
#        {'start': '2021-01-01T00:00:00Z',
#         'end': '2021-03-31T00:00:00Z',
#         'id': '2021-Q1',
#         'name': '2021-Q1',
#         'names': {'en': '2021-Q1'}},
#        {'start': '2021-04-01T00:00:00Z',
#         'end': '2021-06-30T00:00:00Z',
#         'id': '2021-Q2',
#         'name': '2021-Q2',
#         'names': {'en': '2021-Q2'}},
#        {'start': '2021-07-01T00:00:00Z',
#         'end': '2021-09-30T00:00:00Z',
#         'id': '2021-Q3',
#         'name': '2021-Q3',
#         'names': {'en': '2021-Q3'}},
#        {'start': '2021-10-01T00:00:00Z',
#         'end': '2021-12-31T00:00:00Z',
#         'id': '2021-Q4',
#         'name': '2021-Q4',
#         'names': {'en': '2021-Q4'}},
#        {'start': '2022-01-01T00:00:00Z',
#         'end': '2022-03-31T00:00:00Z',
#         'id': '2022-Q1',
#         'name': '2022-Q1',
#         'names': {'en': '2022-Q1'}},
#        {'start': '2022-04-01T00:00:00Z',
#         'end': '2022-06-30T00:00:00Z',
#         'id': '2022-Q2',
#         'name': '2022-Q2',
#         'names': {'en': '2022-Q2'}},
#        {'start': '2022-07-01T00:00:00Z',
#         'end': '2022-09-30T00:00:00Z',
#         'id': '2022-Q3',
#         'name': '2022-Q3',
#         'names': {'en': '2022-Q3'}}]}]},
#    'attributes': {'dataSet': [],
#     'series': [{'id': 'UNIT_MEASURE',
#       'name': 'Unit of Measure',
#       'names': {'en': 'Unit of Measure'},
#       'roles': ['UNIT_MEASURE'],
#       'relationship': {'dimensions': ['MEASURE']},
#       'values': [{'id': 'NUM',
#         'order': 1,
#         'name': 'Number',
#         'names': {'en': 'Number'}}],
#       'annotations': [42]},
#      {'id': 'UNIT_MULT',
#       'name': 'Unit of Multiplier',
#       'names': {'en': 'Unit of Multiplier'},
#       'roles': ['UNIT_MULT'],
#       'relationship': {'dimensions': ['MEASURE']},
#       'values': [{'id': '3',
#         'order': 3,
#         'name': 'Thousands',
#         'names': {'en': 'Thousands'}}],
#       'annotations': [43]}],
#     'observation': [{'id': 'OBS_STATUS',
#       'name': 'Observation Status',
#       'names': {'en': 'Observation Status'},
#       'roles': ['OBS_STATUS'],
#       'relationship': {'primaryMeasure': 'OBS_VALUE'},
#       'values': [{'id': 'y',
#         'order': 14,
#         'name': 'estimate has a relative standard error between 25% and 50% and should be used with caution',
#         'names': {'en': 'estimate has a relative standard error between 25% and 50% and should be used with caution'}},
#        {'id': 'z',
#         'order': 15,
#         'name': 'estimate has a relative standard error greater than 50% and is considered too unreliable for general use',
#         'names': {'en': 'estimate has a relative standard error greater than 50% and is considered too unreliable for general use'}}]},
#      {'id': 'OBS_COMMENT',
#       'name': 'Observation Comment',
#       'names': {'en': 'Observation Comment'},
#       'roles': ['OBS_COMMENT'],
#       'relationship': {'primaryMeasure': 'OBS_VALUE'},
#       'values': []}]},
#    'annotations': [{'type': 'NonProductionDataflow',
#      'text': 'true',
#      'texts': {'en': 'true'}},
#     {'title': 'TIME_PERIOD', 'type': 'LAYOUT_COLUMN'},
#     {'title': 'SECTOR', 'type': 'LAYOUT_ROW'},
#     {'title': 'TSEST', 'type': 'LAYOUT_ROW_SECTION'},
#     {'title': 'MEASURE=M1,INDUSTRY=TOT,REGION=AUS,FREQ=Q,TIME_PERIOD_START=2020-Q1',
#      'type': 'DEFAULT'},
#     {'type': 'EXT_RESOURCE',
#      'text': 'Methodology|https://www.abs.gov.au/statistics/labour/employment-and-unemployment/job-vacancies-australia/latest-release|https://www.abs.gov.au/ausstats/wmdata.nsf/activeimages/methodology/$File/methodology.png',
#      'texts': {'en': 'Methodology|https://www.abs.gov.au/statistics/labour/employment-and-unemployment/job-vacancies-australia/latest-release|https://www.abs.gov.au/ausstats/wmdata.nsf/activeimages/methodology/$File/methodology.png'}},
#     {'type': 'FURTHER_INFORMATION',
#      'text': 'Job Vacancies',
#      'texts': {'en': 'Job Vacancies'}},
#     {'type': 'FURTHER_INFORMATION',
#      'text': 'Standard Error of Job Vacancies',
#      'texts': {'en': 'Standard Error of Job Vacancies'}},
#     {'type': 'ORDER', 'text': '70', 'texts': {'en': '70'}},
#     {'type': 'ORDER', 'text': '20', 'texts': {'en': '20'}},
#     {'type': 'ORDER', 'text': '10', 'texts': {'en': '10'}},
#     {'type': 'ORDER', 'text': '7330', 'texts': {'en': '7330'}},
#     {'type': 'ORDER', 'text': '6880', 'texts': {'en': '6880'}},
#     {'type': 'ORDER', 'text': '1010', 'texts': {'en': '1010'}},
#     {'type': 'ORDER', 'text': '3150', 'texts': {'en': '3150'}},
#     {'type': 'ORDER', 'text': '720', 'texts': {'en': '720'}},
#     {'type': 'ORDER', 'text': '3770', 'texts': {'en': '3770'}},
#     {'type': 'ORDER', 'text': '4910', 'texts': {'en': '4910'}},
#     {'type': 'ORDER', 'text': '7130', 'texts': {'en': '7130'}},
#     {'type': 'ORDER', 'text': '7620', 'texts': {'en': '7620'}},
#     {'type': 'ORDER', 'text': '6680', 'texts': {'en': '6680'}},
#     {'type': 'ORDER', 'text': '5500', 'texts': {'en': '5500'}},
#     {'type': 'ORDER', 'text': '6210', 'texts': {'en': '6210'}},
#     {'type': 'ORDER', 'text': '4420', 'texts': {'en': '4420'}},
#     {'type': 'ORDER', 'text': '3410', 'texts': {'en': '3410'}},
#     {'type': 'ORDER', 'text': '7910', 'texts': {'en': '7910'}},
#     {'type': 'ORDER', 'text': '5040', 'texts': {'en': '5040'}},
#     {'type': 'ORDER', 'text': '6400', 'texts': {'en': '6400'}},
#     {'type': 'ORDER', 'text': '5940', 'texts': {'en': '5940'}},
#     {'type': 'ORDER', 'text': '1', 'texts': {'en': '1'}},
#     {'type': 'FULL_NAME', 'text': 'Original', 'texts': {'en': 'Original'}},
#     {'type': 'ORDER', 'text': '3', 'texts': {'en': '3'}},
#     {'type': 'FULL_NAME', 'text': 'Trend', 'texts': {'en': 'Trend'}},
#     {'type': 'ORDER', 'text': '2', 'texts': {'en': '2'}},
#     {'type': 'FULL_NAME',
#      'text': 'Seasonally Adjusted',
#      'texts': {'en': 'Seasonally Adjusted'}},
#     {'type': 'OTHER_LINKS',
#      'text': 'https://www.abs.gov.au/websitedbs/D3310114.nsf/home/Time+Series+Analysis:+The+Basics',
#      'texts': {'en': 'https://www.abs.gov.au/websitedbs/D3310114.nsf/home/Time+Series+Analysis:+The+Basics'}},
#     {'type': 'ORDER', 'text': '30', 'texts': {'en': '30'}},
#     {'type': 'ORDER', 'text': '40', 'texts': {'en': '40'}},
#     {'type': 'ORDER', 'text': '80', 'texts': {'en': '80'}},
#     {'type': 'ORDER', 'text': '90', 'texts': {'en': '90'}},
#     {'type': 'ORDER', 'text': '60', 'texts': {'en': '60'}},
#     {'type': 'ORDER', 'text': '50', 'texts': {'en': '50'}},
#     {'type': 'CONTEXT',
#      'text': 'If a unit multiplier exists the data is recorded according to the combination of the unit multiplier and the unit of measure.',
#      'texts': {'en': 'If a unit multiplier exists the data is recorded according to the combination of the unit multiplier and the unit of measure.'}},
#     {'type': 'CONTEXT',
#      'text': 'Codes for unit of multiplier are the exponent in base 10 so that multiplying the observation by 10^UNIT_MULT gives a value expressed in the unit of measure.',
#      'texts': {'en': 'Codes for unit of multiplier are the exponent in base 10 so that multiplying the observation by 10^UNIT_MULT gives a value expressed in the unit of measure.'}}]}}}

# %%
# Select 
country = data[1][1]['country']['value']
gdp_value = data[1][1]['value']

print("Country: " + country)
print("GDP Value: " + str(gdp_value))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [3], in <cell line: 2>()
#       1 # Select
# ----> 2 country = data[1][1]['country']['value']
#       3 gdp_value = data[1][1]['value']
#       5 print("Country: " + country)
#
# KeyError: 1
