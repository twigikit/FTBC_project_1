# %%
import pandas as pd
import json
import hvplot.pandas

# %%
#suppress warnings
import warnings
warnings.filterwarnings('ignore')

# %%
df_location = pd.read_csv('./Resources/state_coordinate.csv')

# %%
df_location
# Out:
#   state  Latitude  Longitude  unemployment_rate
# 0   NSW -33.86785  151.20732               3.63
# 1   VIC -37.81753  144.96715               3.74
# 2   QLD -27.47126  153.02385               3.97
# 3    SA -34.92610  138.59988               4.47
# 4    WA -31.95264  115.85741               3.36
# 5   TAS -42.88164  147.33162               4.17
# 6    NT -12.46106  130.84166               3.92
# 7   ACT -35.30654  149.12656               3.15

# %%
df_location.hvplot.points("Longitude", "Latitude", geo = True, size = 100, tiles = "OSM").opts(width = 500, height = 400)
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Longitude,Latitude]

# %%
with open('./Resources/aus_state.geojson') as f:
    data = json.load(f)

# %%
data["features"]
# Out:
# [{'type': 'Feature',
#   'geometry': {'type': 'MultiPolygon',
#    'coordinates': [[[[159.07, -31.5023],
#       [159.0664, -31.4993],
#       [159.069, -31.4983],
#       [159.07, -31.5023]]],
#     [[[152.2311, -32.7089],
#       [152.2263, -32.7076],
#       [152.2298, -32.7053],
#       [152.2311, -32.7089]]],
#     [[[151.1691, -33.8487],
#       [151.1693, -33.8466],
#       [151.1738, -33.846],
#       [151.1733, -33.8495],
#       [151.1691, -33.8487]]],
#     [[[152.3334, -32.6174],
#       [152.3361, -32.6198],
#       [152.3366, -32.6234],
#       [152.3336, -32.6243],
#       [152.331, -32.6207],
#       [152.3334, -32.6174]]],
#     [[[152.2231, -32.6858],
#       [152.2276, -32.686],
#       [152.2261, -32.6917],
#       [152.2228, -32.6901],
#       [152.2231, -32.6858]]],
#     [[[151.2431, -33.5389],
#       [151.2394, -33.5402],
#       [151.2376, -33.5425],
#       [151.2348, -33.5406],
#       [151.2367, -33.537],
#       [151.2441, -33.5373],
# ...
